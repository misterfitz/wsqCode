# %% [markdown]
# # Yahoo Finance: Daily Price Bars
# 1. Install yfinance: pip install yfinance
# 2. Documentation: https://pypi.org/project/yfinance/
# 3. GitHub: https://github.com/ranaroussi/yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
univ = ['AAPL','MSFT','GOOG','AMZN','FB','TSLA','BRK-A','NVDA','V']
stock_px = yf.download(univ, start="2019-01-01")
# Out:
# [*********************100%***********************]  9 of 9 completed
#
# 1 Failed download:
# ['FB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')

# %%
stock_px
# Out:
# Price                       Adj Close                                        \
# Ticker                           AAPL        AMZN     BRK-A  FB        GOOG
# Date
# 2019-01-02 00:00:00+00:00   37.708588   76.956497  304057.0 NaN   52.164394
# 2019-01-03 00:00:00+00:00   33.952557   75.014000  287000.0 NaN   50.678543
# 2019-01-04 00:00:00+00:00   35.401955   78.769501  292500.0 NaN   53.404346
# 2019-01-07 00:00:00+00:00   35.323154   81.475502  295400.0 NaN   53.288631
# 2019-01-08 00:00:00+00:00   35.996529   82.829002  294300.0 NaN   53.682163
# ...                               ...         ...       ...  ..         ...
# 2024-11-04 00:00:00+00:00  221.766006  195.779999  664750.0 NaN  170.679993
# 2024-11-05 00:00:00+00:00  223.204422  199.500000  666684.0 NaN  171.410004
# 2024-11-06 00:00:00+00:00  222.475235  207.089996  703000.0 NaN  178.330002
# 2024-11-07 00:00:00+00:00  227.229996  210.050003  688252.0 NaN  182.279999
# 2024-11-08 00:00:00+00:00  226.960007  208.179993  695878.0 NaN  179.860001
#
# Price                                                                      \
# Ticker                           MSFT        NVDA        TSLA           V
# Date
# 2019-01-02 00:00:00+00:00   95.501328    3.378323   20.674667  127.731453
# 2019-01-03 00:00:00+00:00   91.988022    3.174215   20.024000  123.128418
# 2019-01-04 00:00:00+00:00   96.266327    3.377579   21.179333  128.432938
# 2019-01-07 00:00:00+00:00   96.389084    3.556390   22.330667  130.748840
# 2019-01-08 00:00:00+00:00   97.087975    3.467853   22.356667  131.459991
# ...                               ...         ...         ...         ...
# 2024-11-04 00:00:00+00:00  408.459991  136.050003  242.839996  291.850006
# 2024-11-05 00:00:00+00:00  411.459991  139.910004  251.440002  293.290009
# 2024-11-06 00:00:00+00:00  420.179993  145.610001  288.529999  307.399994
# 2024-11-07 00:00:00+00:00  425.429993  148.880005  296.910004  305.799988
# 2024-11-08 00:00:00+00:00  422.540009  147.630005  321.220001  307.869995
#
# Price                           Close  ...        Open     Volume             \
# Ticker                           AAPL  ...           V       AAPL       AMZN
# Date                                   ...
# 2019-01-02 00:00:00+00:00   39.480000  ...  130.000000  148158800  159662000
# 2019-01-03 00:00:00+00:00   35.547501  ...  131.210007  365248800  139512000
# 2019-01-04 00:00:00+00:00   37.064999  ...  130.440002  234428400  183652000
# 2019-01-07 00:00:00+00:00   36.982498  ...  134.449997  219111200  159864000
# 2019-01-08 00:00:00+00:00   37.687500  ...  137.970001  164101200  177628000
# ...                               ...  ...         ...        ...        ...
# 2024-11-04 00:00:00+00:00  222.009995  ...  291.549988   44944500   38492100
# 2024-11-05 00:00:00+00:00  223.449997  ...  291.709991   28111300   30564800
# 2024-11-06 00:00:00+00:00  222.720001  ...  306.320007   54561100   72292200
# 2024-11-06 00:00:00+00:00  41887574364  561632526  111558691  2211008426
# 2024-11-07 00:00:00+00:00  35352318438  418031721  113474662  1889112043
# 2024-11-08 00:00:00+00:00  32303261101  593832536  100881654  1498480370
# 2024-11-09 00:00:00+00:00  26363283456  390561152   71004040  1153853312
#
# [2140 rows x 54 columns]

# %% [markdown]
# # Kraken Downloadable CSV
# https://support.kraken.com/hc/en-us/articles/360047124832-Downloadable-historical-OHLCVT-Open-High-Low-Close-Volume-Trades-data

# %% [markdown]
# # Binance API for more crypto coins and minute bar data
# 1. Install python-binance: pip install python-binance-us
# 2. Documentation: https://python-binance.readthedocs.io/en/latest/
# 3. GitHub: https://github.com/sammchardy/python-binance

# %%
from binance.client import Client as bnb_client
from datetime import datetime
import pandas as pd 

client = bnb_client() # if you're in the US, please use: client=bnb_client(tld='US')'
px = client.get_historical_klines('BTCUSDT','1d','2024-11-04')
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# /var/folders/4f/9230q1tn743gqfht8kjmqts40000gn/T/ipykernel_93796/2565783830.py in ?()
#       1 from binance.client import Client as bnb_client
#       2 from datetime import datetime
#       3 import pandas as pd
#       4
# ----> 5 client = bnb_client() # if you're in the US, please use: client=bnb_client(tld='US')'
#       6 px = client.get_historical_klines('BTCUSDT','1d','2024-11-04')
#
# /opt/anaconda3/lib/python3.12/site-packages/binance/client.py in ?(self, api_key, api_secret, requests_params, tld, base_endpoint, testnet, private_key, private_key_pass, ping)
#
# /opt/anaconda3/lib/python3.12/site-packages/binance/client.py in ?(self)
#
# /opt/anaconda3/lib/python3.12/site-packages/binance/client.py in ?(self, path, signed, version, **kwargs)
#     530 'Could not get source, probably due dynamically evaluated source code.'
#
# /opt/anaconda3/lib/python3.12/site-packages/binance/client.py in ?(self, method, path, signed, version, **kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/binance/client.py in ?(self, method, uri, signed, force_params, **kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/binance/client.py in ?(response)
#
# BinanceAPIException: APIError(code=0): Service unavailable from a restricted location according to 'b. Eligibility' in https://www.binance.com/en/terms. Please contact customer service if you believe you received this message in error.

# %%
px

# %%
def format_binance(data):
    columns = ['open_time','open','high','low','close','volume','close_time','quote_volume',
    'num_trades','taker_base_volume','taker_quote_volume','ignore']

    data = pd.DataFrame(data,columns = columns)
    
    # Convert from POSIX timestamp (number of millisecond since jan 1, 1970)
    data['open_time'] = data['open_time'].map(lambda x: datetime.fromtimestamp(x/1000))
    data['close_time'] = data['close_time'].map(lambda x: datetime.fromtimestamp(x/1000))
    return data

# %%
format_binance(px)

# %%
# get all the historical data
px = format_binance(client.get_historical_klines('BTCUSDT','1d',0))

# %%
px

# %%
# interval strings
client.KLINE_INTERVAL_1MINUTE

# %%
# Get minute bar data
px = client.get_historical_klines('BTCUSDT','1m','2021-10-20 23:00:00')

# %%
px = format_binance(px)
px

# %%
px.to_pickle('BINANCE_BTCUSDT_1M.pk')

# %%
pd.read_pickle('BINANCE_BTCUSDT_1M.pk')

# %% [markdown]
# # Other
# - We will add to this as class goes on (pandas datareader, ccxt, quandl, simfin)
